# %%
import numpy as np
import matplotlib.pyplot as plt
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage
from matplotlib.patches import Circle

# Upload files

nmbr_TA = 5
nmbr_NA = 3
fps = 5
N_exp = 0
d_connected = 1 * 1.1


path_to_experiment = f'data_new/{nmbr_TA}TA{nmbr_NA}NA/experiment_{N_exp}'
path_NA = path_to_experiment + "/NA_positions.txt"
path_TA = path_to_experiment + "/TA_positions.txt"
path_performance = path_to_experiment + "/performance.txt"


arr_performance = np.loadtxt(path_performance,delimiter=",", dtype=np.float32)


radius = np.sqrt((nmbr_NA + nmbr_TA)/3.1416)
arr_NA = np.loadtxt(path_NA,delimiter=",", dtype=np.float32)
arr_NA = arr_NA.reshape((-1,nmbr_NA,2))

arr_TA = np.loadtxt(path_TA,delimiter=",", dtype=np.float32)
arr_TA = arr_TA.reshape((-1,nmbr_TA,2))


# Create Video

def plot_circle(center,color, radius=100):
    circle = Circle(center, radius, alpha=0.3,fill=True, color=color)
    ax.add_patch(circle)


# duration of the video

frames = arr_NA.shape[0]
duration = int(frames/fps)

# matplot subplot
fig, ax = plt.subplots()
fig.set_size_inches(8,8)
# method to get frames
def make_frame(t):
     
    # clear
    ax.clear()
    idx = int(t*fps)
    # plotting line
    ax.scatter(arr_NA[idx][:,0],arr_NA[idx][:,1],c='blue')
    ax.scatter(arr_TA[idx][:,0],arr_TA[idx][:,1],c='red')
    for point in arr_NA[idx]:
        circle = Circle(point, d_connected, alpha=0.1,fill=True, color='blue')
        ax.add_patch(circle)
    for point in arr_TA[idx]:
        circle = Circle(point, d_connected, alpha=0.1,fill=True, color='red')
    #    ax.add_patch(circle)
    circle_gral = Circle(np.array([0,0]), radius, fill=False, color='black')
    ax.add_patch(circle_gral)
    ax.set_xlim(-radius,radius)
    ax.set_ylim(-radius,radius)
    ax.set_xlabel("X position (meters)")
    ax.set_ylabel("Y position (meters)")
    ax.set_title("Video of algorithm solving problem for static ")
    # returning numpy image
    return mplfig_to_npimage(fig)
 
# creating animation
animation = VideoClip(make_frame, duration = duration)

# displaying animation with auto play and looping
display(animation.ipython_display(fps = fps, loop = True, autoplay = True))
animation.write_videofile(path_to_experiment + "/video.mp4",fps=fps)


# Create Image

fig_1, (ax1,ax2,ax3) = plt.subplots(1,3)
fig_1.set_size_inches(20,6)
ax1.scatter(arr_NA[0][:,0],arr_NA[0][:,1],c='blue')
ax1.scatter(arr_TA[0][:,0],arr_TA[0][:,1],c='red')
ax1.set_xlim(-radius,radius)
ax1.set_ylim(-radius,radius)
ax1.set_xlabel("X position (meters)")
ax1.set_ylabel("Y position (meters)")
ax1.set_title("Initial positions ")

ax2.scatter(arr_NA[-1][:,0],arr_NA[-1][:,1],c='blue')
ax2.scatter(arr_TA[-1][:,0],arr_TA[-1][:,1],c='red')
ax2.set_xlim(-radius,radius)
ax2.set_ylim(-radius,radius)
ax2.set_xlabel("X position (meters)")
ax2.set_ylabel("Y position (meters)")
ax2.set_title("Final positions")


ax3.plot(arr_performance)
ax3.set_ylabel("Performance")
ax3.set_xlabel("Iteration")
ax3.set_title("Performance function")

fig_1.show()
fig_1.savefig(path_to_experiment + "/image.png")
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:   0%|          | 0/100 [00:00<?, ?it/s, now=None]
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data_new/5TA3NA/experiment_0/video.mp4.
# Moviepy - Writing video data_new/5TA3NA/experiment_0/video.mp4
# Moviepy - Done !
# Moviepy - video ready data_new/5TA3NA/experiment_0/video.mp4

# %%
import numpy as np
import matplotlib.pyplot as plt
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage

# Upload files

nmbr_TA = 15
nmbr_NA = 10
fps = 5
N_exp = 0


for N_exp in range(10):
    path_to_experiment = f'data/{nmbr_TA}TA{nmbr_NA}NA/experiment_{N_exp}'
    path_NA = path_to_experiment + "/NA_positions.txt"
    path_TA = path_to_experiment + "/TA_positions.txt"
    path_performance = path_to_experiment + "/performance.txt"


    arr_performance = np.loadtxt(path_performance,delimiter=",", dtype=np.float32)


    side = np.sqrt(nmbr_NA + nmbr_TA)*100
    arr_NA = np.loadtxt(path_NA,delimiter=",", dtype=np.float32)*100
    arr_NA = arr_NA.reshape((-1,nmbr_NA,2))

    arr_TA = np.loadtxt(path_TA,delimiter=",", dtype=np.float32)*100
    arr_TA = arr_TA.reshape((-1,nmbr_TA,2))


    # Create Video

    # duration of the video

    frames = arr_NA.shape[0]
    duration = int(frames/fps)

    # matplot subplot
    fig, ax = plt.subplots()
    
    # method to get frames
    def make_frame(t):
        
        # clear
        ax.clear()
        idx = int(t*fps)
        
        # plotting line
        ax.scatter(arr_NA[idx][:,0],arr_NA[idx][:,1],c='blue')
        ax.scatter(arr_TA[idx][:,0],arr_TA[idx][:,1],c='red')
        ax.set_xlim(0,side)
        ax.set_ylim(0,side)
        ax.set_xlabel("X position (meters)")
        ax.set_ylabel("Y position (meters)")
        ax.set_title("Video of algorithm solving problem for static ")
        # returning numpy image
        return mplfig_to_npimage(fig)
    
    # creating animation
    animation = VideoClip(make_frame, duration = duration)
    
    # displaying animation with auto play and looping
    display(animation.ipython_display(fps = fps, loop = True, autoplay = True))
    animation.write_videofile(path_to_experiment + "/video.mp4",fps=fps)


    # Create Image

    fig_1, (ax1,ax2,ax3) = plt.subplots(1,3)
    fig_1.set_size_inches(20,6)
    ax1.scatter(arr_NA[0][:,0],arr_NA[0][:,1],c='blue')
    ax1.scatter(arr_TA[0][:,0],arr_TA[0][:,1],c='red')
    ax1.set_xlim(0,side)
    ax1.set_ylim(0,side)
    ax1.set_xlabel("X position (meters)")
    ax1.set_ylabel("Y position (meters)")
    ax1.set_title("Initial positions ")

    ax2.scatter(arr_NA[-1][:,0],arr_NA[-1][:,1],c='blue')
    ax2.scatter(arr_TA[-1][:,0],arr_TA[-1][:,1],c='red')
    ax2.set_xlim(0,side)
    ax2.set_ylim(0,side)
    ax2.set_xlabel("X position (meters)")
    ax2.set_ylabel("Y position (meters)")
    ax2.set_title("Final positions")


    ax3.plot(arr_performance)
    ax3.set_ylabel("Performance")
    ax3.set_xlabel("Iteration")
    ax3.set_title("Performance function")

    fig_1.show()
    fig_1.savefig(path_to_experiment + "/image.png")
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_0/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_0/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_0/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_1/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_1/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_1/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_2/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_2/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_2/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_3/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_3/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_3/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_4/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_4/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_4/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_5/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_5/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_5/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_6/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_6/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_6/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_7/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_7/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_7/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_8/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_8/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_8/video.mp4
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# Moviepy - Done !
# Moviepy - video ready __temp__.mp4
# <div align=middle><video loop='True' autoplay='True'src='data:video/mp4;base64,...' controls>Sorry, seems like your browser doesn't support HTML5 audio/video</video></div>
# Moviepy - Building video data/15TA10NA/experiment_9/video.mp4.
# Moviepy - Writing video data/15TA10NA/experiment_9/video.mp4
# Moviepy - Done !
# Moviepy - video ready data/15TA10NA/experiment_9/video.mp4

# %%
import numpy as np
import matplotlib.pyplot as plt
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage

# Upload files

nmbr_TA = 15
nmbr_NA = 10
fps = 5
N_exp = 2


for N_exp in range(10):
    path_to_experiment = f'data_one_sink/{nmbr_TA}TA{nmbr_NA}NA/experiment_{N_exp}'
    path_NA = path_to_experiment + "/NA_positions.txt"
    path_TA = path_to_experiment + "/TA_positions.txt"
    path_performance = path_to_experiment + "/performance.txt"


    arr_performance = np.loadtxt(path_performance,delimiter=",", dtype=np.float32)


    side = np.sqrt(nmbr_NA + nmbr_TA)*100
    arr_NA = np.loadtxt(path_NA,delimiter=",", dtype=np.float32)*100
    arr_NA = arr_NA.reshape((-1,nmbr_NA,2))

    arr_TA = np.loadtxt(path_TA,delimiter=",", dtype=np.float32)*100
    arr_TA = arr_TA.reshape((-1,nmbr_TA,2))


    # Create Video

    # duration of the video

    frames = arr_NA.shape[0]
    duration = int(frames/fps)

    # matplot subplot
    fig, ax = plt.subplots()
    
    # method to get frames
    def make_frame(t):
        
        # clear
        ax.clear()
        idx = int(t*fps)
        
        # plotting line
        ax.scatter(arr_NA[idx][:,0],arr_NA[idx][:,1],c='blue')
        ax.scatter(arr_TA[idx][:,0],arr_TA[idx][:,1],c='red')
        ax.set_xlim(0,side)
        ax.set_ylim(0,side)
        ax.set_xlabel("X position (meters)")
        ax.set_ylabel("Y position (meters)")
        ax.set_title("Video of algorithm solving problem for static ")
        # returning numpy image
        return mplfig_to_npimage(fig)
    
    # creating animation
    animation = VideoClip(make_frame, duration = duration)
    
    # displaying animation with auto play and looping
    display(animation.ipython_display(fps = fps, loop = True, autoplay = True))
    animation.write_videofile(path_to_experiment + "/video.mp4",fps=fps)


    # Create Image

    fig_1, (ax1,ax2,ax3) = plt.subplots(1,3)
    fig_1.set_size_inches(20,6)
    ax1.scatter(arr_NA[0][:,0],arr_NA[0][:,1],c='blue')
    ax1.scatter(arr_TA[0][:,0],arr_TA[0][:,1],c='red')
    ax1.set_xlim(0,side)
    ax1.set_ylim(0,side)
    ax1.set_xlabel("X position (meters)")
    ax1.set_ylabel("Y position (meters)")
    ax1.set_title("Initial positions ")

    ax2.scatter(arr_NA[-1][:,0],arr_NA[-1][:,1],c='blue')
    ax2.scatter(arr_TA[-1][:,0],arr_TA[-1][:,1],c='red')
    ax2.set_xlim(0,side)
    ax2.set_ylim(0,side)
    ax2.set_xlabel("X position (meters)")
    ax2.set_ylabel("Y position (meters)")
    ax2.set_title("Final positions")


    ax3.plot(arr_performance)
    ax3.set_ylabel("Performance")
    ax3.set_xlabel("Iteration")
    ax3.set_title("Performance function")

    fig_1.show()
    fig_1.savefig(path_to_experiment + "/image.png")
# Out:
# Moviepy - Building video __temp__.mp4.
# Moviepy - Writing video __temp__.mp4
# t:  82%|████████▏ | 82/100 [00:08<00:01, 11.14it/s, now=None]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-9a0522872460> in <module>
#      62
#      63     # displaying animation with auto play and looping
# ---> 64     display(animation.ipython_display(fps = fps, loop = True, autoplay = True))
#      65     animation.write_videofile(path_to_experiment + "/video.mp4",fps=fps)
#      66
#
# ~/.local/lib/python3.8/site-packages/moviepy/video/io/html_tools.py in ipython_display(clip, filetype, maxduration, t, fps, rd_kwargs, center, **html_kwargs)
#     218         clip = clip.to_ImageClip(t)
#     219
# --> 220     return HTML2(html_embed(clip, filetype=filetype, maxduration=maxduration,
#     221                 center=center, rd_kwargs=rd_kwargs, **html_kwargs))
#
# ~/.local/lib/python3.8/site-packages/moviepy/video/io/html_tools.py in html_embed(clip, filetype, maxduration, rd_kwargs, center, **html_kwargs)
#      96             kwargs = {'filename':filename, 'verbose':False, 'preset':'ultrafast'}
#      97             kwargs.update(rd_kwargs)
# ---> 98             clip.write_videofile(**kwargs)
#      99         elif isinstance(clip,AudioClip):
#     100             filename = TEMP_PREFIX+".mp3"
#
# <decorator-gen-180> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~/.local/lib/python3.8/site-packages/moviepy/decorators.py in requires_duration(f, clip, *a, **k)
#      52         raise ValueError("Attribute 'duration' not set")
#      53     else:
# ---> 54         return f(clip, *a, **k)
#      55
#      56
#
# <decorator-gen-179> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~/.local/lib/python3.8/site-packages/moviepy/decorators.py in use_clip_fps_by_default(f, clip, *a, **k)
#     133              for (k,v) in k.items()}
#     134
# --> 135     return f(clip, *new_a, **new_kw)
#
# <decorator-gen-178> in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#
# ~/.local/lib/python3.8/site-packages/moviepy/decorators.py in convert_masks_to_RGB(f, clip, *a, **k)
#      20     if clip.ismask:
#      21         clip = clip.to_RGB()
# ---> 22     return f(clip, *a, **k)
#      23
#      24 @decorator.decorator
#
# ~/.local/lib/python3.8/site-packages/moviepy/video/VideoClip.py in write_videofile(self, filename, fps, codec, bitrate, audio, audio_fps, preset, audio_nbytes, audio_codec, audio_bitrate, audio_bufsize, temp_audiofile, rewrite_audio, remove_temp, write_logfile, verbose, threads, ffmpeg_params, logger)
#     298                                        logger=logger)
#     299
# --> 300         ffmpeg_write_video(self, filename, fps, codec,
#     301                            bitrate=bitrate,
#     302                            preset=preset,
#
# ~/.local/lib/python3.8/site-packages/moviepy/video/io/ffmpeg_writer.py in ffmpeg_write_video(clip, filename, fps, codec, bitrate, preset, withmask, write_logfile, audiofile, verbose, threads, ffmpeg_params, logger)
#     218         nframes = int(clip.duration*fps)
#     219
# --> 220         for t,frame in clip.iter_frames(logger=logger, with_times=True,
#     221                                         fps=fps, dtype="uint8"):
#     222             if withmask:
#
# ~/.local/lib/python3.8/site-packages/moviepy/Clip.py in iter_frames(self, fps, with_times, logger, dtype)
#     470         logger = proglog.default_bar_logger(logger)
#     471         for t in logger.iter_bar(t=np.arange(0, self.duration, 1.0/fps)):
# --> 472             frame = self.get_frame(t)
#     473             if (dtype is not None) and (frame.dtype != dtype):
#     474                 frame = frame.astype(dtype)
#
# <decorator-gen-136> in get_frame(self, t)
#
# ~/.local/lib/python3.8/site-packages/moviepy/decorators.py in wrapper(f, *a, **kw)
#      87         new_kw = {k: fun(v) if k in varnames else v
#      88                  for (k,v) in kw.items()}
# ---> 89         return f(*new_a, **new_kw)
#      90     return decorator.decorator(wrapper)
#      91
#
# ~/.local/lib/python3.8/site-packages/moviepy/Clip.py in get_frame(self, t)
#      91                 return frame
#      92         else:
# ---> 93             return self.make_frame(t)
#      94
#      95     def fl(self, fun, apply_to=None, keep_duration=True):
#
# <ipython-input-32-9a0522872460> in make_frame(t)
#      56         ax.set_title("Video of algorithm solving problem for static ")
#      57         # returning numpy image
# ---> 58         return mplfig_to_npimage(fig)
#      59
#      60     # creating animation
#
# ~/.local/lib/python3.8/site-packages/moviepy/video/io/bindings.py in mplfig_to_npimage(fig)
#      21     from matplotlib.backends.backend_agg import FigureCanvasAgg
#      22     canvas = FigureCanvasAgg(fig)
# ---> 23     canvas.draw() # update/draw the elements
#      24
#      25     # get the width and the height to resize the matrix
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in draw(self)
#     386         self.renderer = self.get_renderer(cleared=True)
#     387         with RendererAgg.lock:
# --> 388             self.figure.draw(self.renderer)
#     389             # A GUI class may be need to update a window using this draw, so
#     390             # don't forget to call the superclass.
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/figure.py in draw(self, renderer)
#    1706
#    1707             self.patch.draw(renderer)
# -> 1708             mimage._draw_list_compositing_images(
#    1709                 renderer, self, artists, self.suppressComposite)
#    1710
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2645             renderer.stop_rasterizing()
#    2646
# -> 2647         mimage._draw_list_compositing_images(renderer, self, artists)
#    2648
#    2649         renderer.close_group('axes')
#
# /usr/lib/python3/dist-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, artists, suppress_composite)
#     133     if not_composite or not has_images:
#     134         for a in artists:
# --> 135             a.draw(renderer)
#     136     else:
#     137         # Composite any adjacent images together
#
# /usr/lib/python3/dist-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      36                 renderer.start_filter()
#      37
# ---> 38             return draw(artist, renderer, *args, **kwargs)
#      39         finally:
#      40             if artist.get_agg_filter() is not None:
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in draw(self, renderer, *args, **kwargs)
#    1202
#    1203         ticks_to_draw = self._update_ticks()
# -> 1204         ticklabelBoxes, ticklabelBoxes2 = self._get_tick_bboxes(ticks_to_draw,
#    1205                                                                 renderer)
#    1206
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in _get_tick_bboxes(self, ticks, renderer)
#    1147     def _get_tick_bboxes(self, ticks, renderer):
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1149         return ([tick.label1.get_window_extent(renderer)
#    1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#
# /usr/lib/python3/dist-packages/matplotlib/axis.py in <listcomp>(.0)
#    1147     def _get_tick_bboxes(self, ticks, renderer):
#    1148         """Return lists of bboxes for ticks' label1's and label2's."""
# -> 1149         return ([tick.label1.get_window_extent(renderer)
#    1150                  for tick in ticks if tick.label1.get_visible()],
#    1151                 [tick.label2.get_window_extent(renderer)
#
# /usr/lib/python3/dist-packages/matplotlib/text.py in get_window_extent(self, renderer, dpi)
#     888             raise RuntimeError('Cannot get window extent w/o renderer')
#     889
# --> 890         bbox, info, descent = self._get_layout(self._renderer)
#     891         x, y = self.get_unitless_position()
#     892         x, y = self.get_transform().transform_point((x, y))
#
# /usr/lib/python3/dist-packages/matplotlib/text.py in _get_layout(self, renderer)
#     295             clean_line, ismath = self._preprocess_math(line)
#     296             if clean_line:
# --> 297                 w, h, d = renderer.get_text_width_height_descent(
#     298                     clean_line, self._fontproperties, ismath=ismath)
#     299             else:
#
# /usr/lib/python3/dist-packages/matplotlib/backends/backend_agg.py in get_text_width_height_descent(self, s, prop, ismath)
#     209         flags = get_hinting_flag()
#     210         font = self._get_agg_font(prop)
# --> 211         font.set_text(s, 0.0, flags=flags)
#     212         w, h = font.get_width_height()  # width and height of unrotated string
#     213         d = font.get_descent()
#
# KeyboardInterrupt:

# %%
import numpy as np
import matplotlib.pyplot as plt
from moviepy.editor import VideoClip
from moviepy.video.io.bindings import mplfig_to_npimage



nmbr_TA = 15
nmbr_NA = 10
fps = 5
N_exp = 1


path_to_experiment = f'data_one_sink/{nmbr_TA}TA{nmbr_NA}NA/experiment_{N_exp}'
path_NA = path_to_experiment + "/NA_positions.txt"
path_TA = path_to_experiment + "/TA_positions.txt"
path_performance = path_to_experiment + "/performance.txt"


arr_performance = np.loadtxt(path_performance,delimiter=",", dtype=np.float32)

side = np.sqrt(nmbr_NA + nmbr_TA)
arr_NA = np.loadtxt(path_NA,delimiter=",", dtype=np.float32)
arr_NA = arr_NA.reshape((-1,nmbr_NA,2))

arr_TA = np.loadtxt(path_TA,delimiter=",", dtype=np.float32)
arr_TA = arr_TA.reshape((-1,nmbr_TA,2))


# Create Image


# Create Image

fig_1, ax = plt.subplots(2,3)
fig_1.set_size_inches(20,12)

ax[0,0].scatter(arr_TA[0][1:,0],arr_TA[0][1:,1],c='red',marker='x',linewidths=4)
ax[0,0].scatter(arr_NA[0][:,0],arr_NA[0][:,1],c='blue',linewidths=3)
ax[0,0].scatter(arr_TA[0][0,0],arr_TA[0][0,1],c='purple',marker='d',linewidths=4)
ax[0,0].set_xlim(0,side)
ax[0,0].set_ylim(0,side)
ax[0,0].set_xlabel("X position (km)", fontsize=18)
ax[0,0].set_ylabel("Y position (km)", fontsize=18)
ax[0,0].set_title("t = 0 s", fontsize=20)
ax[0,0].legend(['Task Agents', 'Communication Agents', 'AP'],loc='upper right', fontsize=10)

ax[0,1].scatter(arr_TA[20-1][1:,0],arr_TA[20-1][1:,1],c='red',marker='x',linewidths=4)
ax[0,1].scatter(arr_NA[20-1][:,0],arr_NA[20-1][:,1],c='blue',linewidths=3)
ax[0,1].scatter(arr_TA[20-1][0,0],arr_TA[20-1][0,1],c='purple',marker='d',linewidths=4)
ax[0,1].scatter(arr_NA[0:20:5,:,0],arr_NA[0:20:5,:,1],c='blue',linewidths=1,alpha =0.1)
ax[0,1].scatter(arr_TA[0:20:5,1:,0],arr_TA[0:20:5,1:,1],c='red',marker='o',linewidths=1,alpha=0.1)
ax[0,1].set_xlim(0,side)
ax[0,1].set_ylim(0,side)
ax[0,1].set_xlabel("X position (km)", fontsize=18)
ax[0,1].set_ylabel("Y position (km)", fontsize=18)
ax[0,1].set_title("t = 4 s", fontsize=20)
ax[0,1].legend(['Task Agents', 'Communication Agents', 'AP'],loc='upper right', fontsize=10)


ax[0,2].scatter(arr_TA[40-1][1:,0],arr_TA[40-1][1:,1],c='red',marker='x',linewidths=4)
ax[0,2].scatter(arr_NA[40-1][:,0],arr_NA[40-1][:,1],c='blue',linewidths=3)
ax[0,2].scatter(arr_TA[40-1][0,0],arr_TA[40-1][0,1],c='purple',marker='d',linewidths=4)
ax[0,2].scatter(arr_NA[20:40:5,:,0],arr_NA[20:40:5,:,1],c='blue',linewidths=1,alpha =0.1)
ax[0,2].scatter(arr_TA[20:40:5,1:,0],arr_TA[20:40:5,1:,1],c='red',marker='o',linewidths=1,alpha=0.1)
ax[0,2].set_xlim(0,side)
ax[0,2].set_ylim(0,side)
ax[0,2].set_xlabel("X position (km)", fontsize=18)
ax[0,2].set_ylabel("Y position (km)", fontsize=18)
ax[0,2].set_title("t = 8 s", fontsize=20)
ax[0,2].legend(['Task Agents', 'Communication Agents', 'AP'],loc='upper right', fontsize=10)


ax[1,0].scatter(arr_TA[60-1][1:,0],arr_TA[60-1][1:,1],c='red',marker='x',linewidths=4)
ax[1,0].scatter(arr_NA[60-1][:,0],arr_NA[60-1][:,1],c='blue',linewidths=3)
ax[1,0].scatter(arr_TA[60-1][0,0],arr_TA[60-1][0,1],c='purple',marker='d',linewidths=4)
ax[1,0].scatter(arr_NA[40:60:5,:,0],arr_NA[40:60:5,:,1],c='blue',linewidths=1,alpha =0.1)
ax[1,0].scatter(arr_TA[40:60:5,1:,0],arr_TA[40:60:5,1:,1],c='red',marker='o',linewidths=1,alpha=0.1)
ax[1,0].set_xlim(0,side)
ax[1,0].set_ylim(0,side)
ax[1,0].set_xlabel("X position (km)", fontsize=18)
ax[1,0].set_ylabel("Y position (km)", fontsize=18)
ax[1,0].set_title("t = 12 s", fontsize=20)
ax[1,0].legend(['Task Agents', 'Communication Agents', 'AP'],loc='upper right', fontsize=10)

ax[1,1].scatter(arr_TA[80-1][1:,0],arr_TA[80 -1][1:,1],c='red',marker='x',linewidths=4)
ax[1,1].scatter(arr_NA[80-1][:,0],arr_NA[80-1][:,1],c='blue',linewidths=3)
ax[1,1].scatter(arr_TA[80-1][0,0],arr_TA[80-1][0,1],c='purple',marker='d',linewidths=4)
ax[1,1].scatter(arr_NA[60:80:5,:,0],arr_NA[60:80:5,:,1],c='blue',linewidths=1,alpha =0.1)
ax[1,1].scatter(arr_TA[60:80:5,1:,0],arr_TA[60:80:5,1:,1],c='red',marker='o',linewidths=1,alpha=0.1)
ax[1,1].set_xlim(0,side)
ax[1,1].set_ylim(0,side)
ax[1,1].set_xlabel("X position (km)", fontsize=18)
ax[1,1].set_ylabel("Y position (km)", fontsize=18)
ax[1,1].set_title("t = 16 s", fontsize=20)
ax[1,1].legend(['Task Agents', 'Communication Agents', 'AP'],loc='upper right', fontsize=10)

ax[1,2].scatter(arr_TA[100-1][1:,0],arr_TA[100-1][1:,1],c='red',marker='x',linewidths=4)
ax[1,2].scatter(arr_NA[100-1][:,0],arr_NA[100-1][:,1],c='blue',linewidths=3)
ax[1,2].scatter(arr_TA[100-1][0,0],arr_TA[100-1][0,1],c='purple',marker='d',linewidths=4)
ax[1,2].scatter(arr_NA[80:99:5,:,0],arr_NA[80:99:5,:,1],c='blue',linewidths=1,alpha =0.1)
ax[1,2].scatter(arr_TA[80:99:5,1:,0],arr_TA[80:99:5,1:,1],c='red',marker='o',linewidths=1,alpha=0.1)
ax[1,2].set_xlim(0,side)
ax[1,2].set_ylim(0,side)
ax[1,2].set_xlabel("X position (km)", fontsize=18)
ax[1,2].set_ylabel("Y position (km)", fontsize=18)
ax[1,2].set_title("t = 20 s", fontsize=20)
ax[1,2].legend(['Task Agents', 'Communication Agents', 'AP'],loc='upper right', fontsize=10)

fig_1.show()
fig_1.savefig("plots/one_sink_cases.png")


time = np.arange(0,142,1)/142*20
plt.figure()
plt.plot(time,arr_performance)
plt.xlabel("Time (s)", fontsize=18)
plt.ylabel("Performance Function", fontsize=18)
plt.savefig("plots/perf_one_sink.png")
